# %%
import pandas as pd
from itertools import product

# %%
def list_then_eliminate(train: pd.DataFrame, outcome: str, Hall: pd.DataFrame) -> pd.DataFrame:
    
    # Version space, initially with all possibilities
    version_space = Hall.copy()
    
    # For each training example x...
    for _, x in train.iterrows():

        # ...remove from version_space any non-compatible hypothesis
        query = " & ".join([f"`{k}`=='{v}'" for k, v in x.drop(outcome).items()])
        query = f"{query} & `{outcome}`!={x[outcome]}"
        version_space = version_space.drop(version_space.query(query).index)

    return version_space

# %%
df = pd.read_csv("../data/play_sport.csv")

df
# Out:
#      sky airtemp humidity    wind water forecast  enjoysport
# 0  sunny    warm   normal  strong  warm     same        True
# 1  sunny    warm     high  strong  warm     same        True
# 2  rainy    cold     high  strong  warm   change       False
# 3  sunny    warm     high  strong  cool   change        True

# %%
# Complete hypothesis space given training data (compacted)
attrs = df.keys()
H = {key: df[key].unique() for key in attrs}
H
# Out:
# {'sky': array(['sunny', 'rainy'], dtype=object),
#  'airtemp': array(['warm', 'cold'], dtype=object),
#  'humidity': array(['normal', 'high'], dtype=object),
#  'wind': array(['strong'], dtype=object),
#  'water': array(['warm', 'cool'], dtype=object),
#  'forecast': array(['same', 'change'], dtype=object),
#  'enjoysport': array([ True, False])}

# %%
# Complete hypothesis space given training data (enumerated)
combinations = list(product(*H.values()))
Hall = pd.DataFrame(combinations, columns=H.keys())

Hall
# Out:
#       sky airtemp humidity    wind water forecast  enjoysport
# 0   sunny    warm   normal  strong  warm     same        True
# 1   sunny    warm   normal  strong  warm     same       False
# 2   sunny    warm   normal  strong  warm   change        True
# 3   sunny    warm   normal  strong  warm   change       False
# 4   sunny    warm   normal  strong  cool     same        True
# ..    ...     ...      ...     ...   ...      ...         ...
# 59  rainy    cold     high  strong  warm   change       False
# 60  rainy    cold     high  strong  cool     same        True
# 61  rainy    cold     high  strong  cool     same       False
# 62  rainy    cold     high  strong  cool   change        True
# 63  rainy    cold     high  strong  cool   change       False
#
# [64 rows x 7 columns]

# %%
version_space = list_then_eliminate(df, 'enjoysport', Hall)

print(f"Number of original hypothesis   : {len(Hall)}")
print(f"Number of consistent hypothesis : {len(version_space)}")

version_space
# Out:
# Number of original hypothesis   : 64
# Number of consistent hypothesis : 60
#       sky airtemp humidity    wind water forecast  enjoysport
# 0   sunny    warm   normal  strong  warm     same        True
# 2   sunny    warm   normal  strong  warm   change        True
# 3   sunny    warm   normal  strong  warm   change       False
# 4   sunny    warm   normal  strong  cool     same        True
# 5   sunny    warm   normal  strong  cool     same       False
# 6   sunny    warm   normal  strong  cool   change        True
# 7   sunny    warm   normal  strong  cool   change       False
# 8   sunny    warm     high  strong  warm     same        True
# 10  sunny    warm     high  strong  warm   change        True
# 11  sunny    warm     high  strong  warm   change       False
# 12  sunny    warm     high  strong  cool     same        True
# 13  sunny    warm     high  strong  cool     same       False
# 14  sunny    warm     high  strong  cool   change        True
# 16  sunny    cold   normal  strong  warm     same        True
# 17  sunny    cold   normal  strong  warm     same       False
# 18  sunny    cold   normal  strong  warm   change        True
# 19  sunny    cold   normal  strong  warm   change       False
# 20  sunny    cold   normal  strong  cool     same        True
# 21  sunny    cold   normal  strong  cool     same       False
# 22  sunny    cold   normal  strong  cool   change        True
# 23  sunny    cold   normal  strong  cool   change       False
# 24  sunny    cold     high  strong  warm     same        True
# 25  sunny    cold     high  strong  warm     same       False
# 26  sunny    cold     high  strong  warm   change        True
# 27  sunny    cold     high  strong  warm   change       False
# 28  sunny    cold     high  strong  cool     same        True
# 29  sunny    cold     high  strong  cool     same       False
# 30  sunny    cold     high  strong  cool   change        True
# 31  sunny    cold     high  strong  cool   change       False
# 32  rainy    warm   normal  strong  warm     same        True
# 33  rainy    warm   normal  strong  warm     same       False
# 34  rainy    warm   normal  strong  warm   change        True
# 35  rainy    warm   normal  strong  warm   change       False
# 36  rainy    warm   normal  strong  cool     same        True
# 37  rainy    warm   normal  strong  cool     same       False
# 38  rainy    warm   normal  strong  cool   change        True
# 39  rainy    warm   normal  strong  cool   change       False
# 40  rainy    warm     high  strong  warm     same        True
# 41  rainy    warm     high  strong  warm     same       False
# 42  rainy    warm     high  strong  warm   change        True
# 43  rainy    warm     high  strong  warm   change       False
# 44  rainy    warm     high  strong  cool     same        True
# 45  rainy    warm     high  strong  cool     same       False
# 46  rainy    warm     high  strong  cool   change        True
# 47  rainy    warm     high  strong  cool   change       False
# 48  rainy    cold   normal  strong  warm     same        True
# 49  rainy    cold   normal  strong  warm     same       False
# 50  rainy    cold   normal  strong  warm   change        True
# 51  rainy    cold   normal  strong  warm   change       False
# 52  rainy    cold   normal  strong  cool     same        True
# 53  rainy    cold   normal  strong  cool     same       False
# 54  rainy    cold   normal  strong  cool   change        True
# 55  rainy    cold   normal  strong  cool   change       False
# 56  rainy    cold     high  strong  warm     same        True
# 57  rainy    cold     high  strong  warm     same       False
# 59  rainy    cold     high  strong  warm   change       False
# 60  rainy    cold     high  strong  cool     same        True
# 61  rainy    cold     high  strong  cool     same       False
# 62  rainy    cold     high  strong  cool   change        True
# 63  rainy    cold     high  strong  cool   change       False
